# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from config_load import INPUT_FOLDER_PATH, OUTPUT_DATA_PATH
import config_load

# %%
INPUT_FOLDER_PATH
# Out:
# '/home/sagemaker-user/dynamic_risk_assesment_system/dataset/practicedata'

# %%
OUTPUT_DATA_PATH
# Out:
# '/home/sagemaker-user/dynamic_risk_assesment_system/dataset/ingesteddata'

# %%
config_load.MODEL_PATH
# Out:
# '/home/sagemaker-user/dynamic_risk_assesment_system/models/practicemodels'

# %%
config_load.PROD_DEPLOYMENT_PATH
# Out:
# '/home/sagemaker-user/dynamic_risk_assesment_system/models/production_deployment'

# %%
import os
import pandas as pd
file_names = []
for file in os.listdir(config_load.INPUT_FOLDER_PATH):
    print(file)
    file_path = os.path.join(config_load.INPUT_FOLDER_PATH, file)
    print(file_path) 
    df_tmp = pd.read_csv(file_path)
    print(df_tmp.head(n=1))
    file = os.path.join(*file_path.split(os.path.sep)[-3:])
    print(file)
    file_names.append(file)
# Out:
# dataset1.csv
# /home/sagemaker-user/dynamic_risk_assesment_system/dataset/practicedata/dataset1.csv
#   corporation  lastmonth_activity  lastyear_activity  number_of_employees  \
# 0        nciw                 100               1359                    1
#
#    exited
# 0       0
# dataset/practicedata/dataset1.csv
# dataset2.csv
# /home/sagemaker-user/dynamic_risk_assesment_system/dataset/practicedata/dataset2.csv
#   corporation  lastmonth_activity  lastyear_activity  number_of_employees  \
# 0        abcd                  78               1024                   12
#
#    exited
# 0       1
# dataset/practicedata/dataset2.csv

# %%
path = '../dataset/ingesteddata/finaldata.csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#    corporation  lastmonth_activity  lastyear_activity  number_of_employees  \
# 0         nciw                 100               1359                    1
# 1         lsid                  68                282                   14
# 2         pwls                  71                949                   40
# 3         bqlx                 686               3782                  103
# 4         zmei                  45                655                    7
# 5         wosl                   0                 18                   21
# 6         xcvb                 189                961                   18
# 7         dfgh                  16               1028                   33
# 8         ngrd                   9                 45                    1
# 9         xful                   0                 67                   14
# 10        kshe                  48                986                   22
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#    corporation  lastmonth_activity  lastyear_activity  number_of_employees  \
# 0         nciw                 100               1359                    1
# 1         lsid                  68                282                   14
# 2         pwls                  71                949                   40
# 3         bqlx                 686               3782                  103
# 4         zmei                  45                655                    7
# 5         wosl                   0                 18                   21
# 6         xcvb                 189                961                   18
# 7         dfgh                  16               1028                   33
# 8         ngrd                   9                 45                    1
# 9         xful                   0                 67                   14
# 10        kshe                  48                986                   22
# ...

# %%
X = df.pop('exited')
X
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
# 5     1
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    0
# 13    1
# 14    1
# 15    1
# 16    0
# 17    1
# 18    0
# 19    0
# 20    1
# 21    1
# 22    0
# 23    1
# 24    1
# 25    0
# 26    1
# 27    0
# 28    1
# 29    1
# 30    1
# 31    0
# 32    1
# 33    1
# 34    0
# 35    1
# Name: exited, dtype: int64

# %%
X = df.drop(['corporation'], axis=1)
X
# Out:
#     lastmonth_activity  lastyear_activity  number_of_employees
# 0                  100               1359                    1
# 1                   68                282                   14
# 2                   71                949                   40
# 3                  686               3782                  103
# 4                   45                655                    7
# 5                    0                 18                   21
# 6                  189                961                   18
# 7                   16               1028                   33
# 8                    9                 45                    1
# 9                    0                 67                   14
# 10                  48                986                   22
# 11                  52                650                   11
# 12                1090               2452                    9
# 13                   6                 88                   90
# ...

# %%
import pandas as pd

# %%
def fun(df = None):
    if df is None: 
        print("df is none")
    elif isinstance(df, pd.DataFrame):
        print("Df is dataframe")

# %%
fun()
# Out:
# df is none
